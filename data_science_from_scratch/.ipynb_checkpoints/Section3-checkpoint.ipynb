# %%
#dataの探索、dataの可視化
# %matplotlib inline
from matplotlib import pyplot as plt
years= [i for i in range(1950,2020,10)]
gdp = [300.2,543.3,1075.9,2862.5,5979.6,10289.7,14958.3]
plt.plot(years,gdp,color="green",marker="o",linestyle="solid")
plt.title("GDP")
plt.ylabel("billions od $")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
movies =["annie hall","ben-hur","casblanca","gandhi","west side story"]
xs = [i+0.5 for i, _ in enumerate(movies)]
num_oscars = [5,11,4,6,2]
plt.bar(xs,num_oscars)
plt.ylabel("#of Academy Award")
plt.xlabel("my favorite movies")
plt.xticks([i + 0.5 for i ,_ in enumerate(movies)],movies)
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from collections import Counter 
grades = [int(i)  for i in ["64","87","92","52","64","23","79","78","84","26"]]
decile = lambda grade:grade // 10 *10
histgram = Counter(decile(grade) for grade in grades)
plt.bar([ x +5 for x in histgram.keys()],histgram.values(),8)
plt.axis([-5,105,0,5])
plt.xticks([10*i for i in range(11)])
plt.xlabel("decile")
plt.ylabel("# of students")
plt.title("distribution of Exam 1 grades")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
variance = [2**i for i in range(8)]
bias_squared = sorted(variance, reverse = True)
total_error = [x + y for x,y in zip(variance,bias_squared)]
xs = [i for i , _ in enumerate(variance)]
plt.plot(xs, variance,"g-",label="variance")
plt.plot(xs , bias_squared,"r-" , label="bias_squared")
plt.plot(xs,total_error ,"b:",label="total_error")
plt.legend(loc=9)
plt.xlabel("model complexity")
plt.title("The bias-variance trade-off")
plt.show()

# %%
friends = [70,65,28,85,95,54,87,98,57,48]
minutes = [156,156,894,264,489,652,465,231,564,261]
labels = ["a","b","c","d","e","f","g","h","i","j","k"]
plt.scatter(friends,minutes)
for label,friend_count,minute_count in zip(labels,friends,minutes):
    plt.annotate(label,xy = (friend_count,minute_count),xytext=(5,-5),textcoords="offset points")

# %%
test1_grade = [90,92,84,96,84]
test2_grade = [100,85,84,62,95]
plt.scatter(test1_grade,test2_grade)
plt.title("axis imcomparable")
plt.xlabel("test1")
plt.ylabel("test2")
plt.axis("equal")
plt.show()
